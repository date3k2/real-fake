# %%
# !pip install transformers datasets torch torchvision

# %%
from datasets import load_dataset

# %%
datasets = load_dataset("./drive/MyDrive/Processed Data", data_files={"train": "**"})
# Out:
# ...
# Resolving data files:   0%|          | 0/9306 [00:00<?, ?it/s]
# ...
# Generating train split: 0 examples [00:00, ? examples/s]

# %%
labels = datasets["train"].features["label"].names
label2id, id2label = dict(), dict()
for i, label in enumerate(labels):
    label2id[label] = str(i)
    id2label[str(i)] = label

# %%
shuffled_dataset = datasets.shuffle(seed=1012)

# %%
shuffled_dataset['train']['label'][:10]
# Out:
# [0, 1, 1, 1, 1, 0, 1, 1, 0, 0]

# %%
train_test = shuffled_dataset['train'].train_test_split(test_size=0.2)

# %%
from huggingface_hub import login

login()

# %%
train_test.push_to_hub("date3k2/raw_real_fake_images")
# Out:
# ...
# Creating parquet from Arrow format:   0%|          | 0/5 [00:00<?, ?ba/s]
# CommitInfo(commit_url='https://huggingface.co/datasets/date3k2/raw_real_fake_images/commit/9297a75ae15ebf6dccfe7963f4d056fb9c80bc37', commit_message='Upload dataset', commit_description='', oid='9297a75ae15ebf6dccfe7963f4d056fb9c80bc37', pr_url=None, pr_revision=None, pr_num=None)
